# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

# %%
net = pd.read_csv("/home/prince/Downloads/Netflix/netflix_titles.csv")

# %%
net
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
net.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
net.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
net.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 447.3+ KB

# %%
net.shape[0]
# Out:
# 8807

# %%
len(net)
# Out:
# 8807

# %%
net.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
net.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
net["director"].fillna("Others", inplace = True)
net
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water           Others
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans           Others
# 4         s5  TV Show           Kota Factory           Others
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb           Others
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
net["country"].fillna("Not Mention", inplace = True)
net
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water           Others
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans           Others
# 4         s5  TV Show           Kota Factory           Others
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb           Others
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
net.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
net.sample()
# Out:
#      show_id     type             title director  \
# 1554   s1555  TV Show  Children of Adam   Others
#
#                                                    cast  country  \
# 1554  Maguy Bou Ghosn, Daniella Rahme, Maxim Khalil,...  Lebanon
#
#              date_added  release_year rating  duration  \
# 1554  December 12, 2020          2020  TV-14  1 Season
#
#                                             listed_in  \
# 1554  International TV Shows, TV Dramas, TV Thrillers
#
#                                             description
# 1554  Amid crime and corruption, the lives of two co...

# %%
import seaborn as sn
sn.histplot(net, x="type")
# Out:
# <AxesSubplot:xlabel='type', ylabel='Count'>

# %%
sn.histplot(net, x="release_year")
# Out:
# <AxesSubplot:xlabel='release_year', ylabel='Count'>

# %%
chart2 = pd.pivot_table(net,index = 'release_year',
               values = 'country',
               aggfunc = ['count'],
               margins = True,
               columns='type',
               margins_name = 'Total Count')
chart2
# Out:
#                count
# type           Movie TV Show Total Count
# release_year
# 1925             NaN     1.0           1
# 1942             2.0     NaN           2
# 1943             3.0     NaN           3
# 1944             3.0     NaN           3
# 1945             3.0     1.0           4
# ...              ...     ...         ...
# 2018           767.0   380.0        1147
# 2019           633.0   397.0        1030
# 2020           517.0   436.0         953
# 2021           277.0   315.0         592
# Total Count   6131.0  2676.0        8807
#
# [75 rows x 3 columns]

# %%
chart2.plot(kind='line', stacked=True)
plt.xlabel('release_year')
plt.ylabel('country')
plt.title('Stacked Bar Chart for release_year and country')
plt.legend(title='Category')
plt.show()

# %%
chart2.plot(kind='bar', stacked=True,)
plt.xlabel('release_year')
plt.ylabel('country')
plt.title('Stacked Bar Chart for release_year and country')
plt.legend(title='Category')
plt.figure(figsize=(15, 10))
plt.show()

# %%
gby = net.groupby('type', as_index=False).count()
gby
# Out:
#       type  show_id  title  director  cast  country  date_added  release_year  \
# 0    Movie     6131   6131      6131  5656     6131        6131          6131
# 1  TV Show     2676   2676      2676  2326     2676        2666          2676
#
#    rating  duration  listed_in  description
# 0    6129      6128       6131         6131
# 1    2674      2676       2676         2676

# %%
chart3 = pd.pivot_table(net,index = 'type',
               values = 'country',
               aggfunc = ['max'],
               margins = True,
               margins_name = 'Total')
chart3
# Out:
#                       max
#                   country
# type
# Movie            Zimbabwe
# TV Show  Uruguay, Germany
# Total            Zimbabwe

# %%
movies_df =net[net['type'] == 'Movie']
movies_by_country = movies_df.groupby('country')['title'].count().reset_index()
movies_by_country = movies_by_country.sort_values(by='title', ascending=False)
top_3_countries = movies_by_country.head(3)
print(top_3_countries)
# Out:
#            country  title
# 526  United States   2058
# 218          India    893
# 327    Not Mention    440

# %%
top_3_countries.plot(kind='barh', stacked=True)
plt.xlabel('count of country')
plt.ylabel('Sum of the movies')
plt.title('Stacked Bar Chart for Categories country and title')
plt.show()

# %%
net.count()
# Out:
# show_id         8807
# type            8807
# title           8807
# director        8807
# cast            7982
# country         8807
# date_added      8797
# release_year    8807
# rating          8803
# duration        8804
# listed_in       8807
# description     8807
# dtype: int64

# %%
net.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          7982 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 447.3+ KB

# %%
net.sample(7)
# Out:
#      show_id     type                                             title  \
# 4558   s4559    Movie                                            Agyaat
# 7876   s7877    Movie  Roberto Saviano: Writing Under Police Protection
# 1284   s1285    Movie                                   The Conjuring 2
# 1740   s1741  TV Show                                    Love & Anarchy
# 6994   s6995    Movie                              Hope Springs Eternal
# 3255   s3256  TV Show                        Who Killed Little Gregory?
# 560     s561    Movie                                           Audible
#
#                      director  \
# 4558          Ram Gopal Varma
# 7876  Pierfrancesco Diliberto
# 1284                James Wan
# 1740                   Others
# 6994           Jack C. Newell
# 3255                   Others
# 560                Matt Ogens
#
#                                                    cast  \
# 4558  Adesh Bhardwaj, Rasika Dugal, Joy Fernandes, R...
# ...

# %%
netflix_shows=net[net['type']=='TV Show']

# %%
netflix_movies =net[net['type']=='Movie']

# %%
netflix_shows
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water           Others
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans           Others
# 4         s5  TV Show           Kota Factory           Others
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V           Others
# 8796   s8797  TV Show             Yunus Emre           Others
# 8797   s8798  TV Show              Zak Storm           Others
# 8800   s8801  TV Show     Zindagi Gulzar Hai           Others
# 8803   s8804  TV Show            Zombie Dumb           Others
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
netflix_shows.count()
# Out:
# show_id         2676
# type            2676
# title           2676
# director        2676
# cast            2326
# country         2676
# date_added      2666
# release_year    2676
# rating          2674
# duration        2676
# listed_in       2676
# description     2676
# dtype: int64

# %%
netflix_movies
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
netflix_movies.count()
# Out:
# show_id         6131
# type            6131
# title           6131
# director        6131
# cast            5656
# country         6131
# date_added      6131
# release_year    6131
# rating          6129
# duration        6128
# listed_in       6131
# description     6131
# dtype: int64

# %%
sn.set(style="darkgrid")
ax = sn.countplot(x="type", data=net, palette="Set2")

# %%
plt.figure(figsize=(12,10))
sn.set(style="darkgrid")
ax = sn.countplot(x="rating", data=net, palette="Set3", order=net['rating'].value_counts().index[0:10])

# %%
net['rating'].value_counts()
# Out:
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %%
sn.histplot(net, x="rating")
# Out:
# <AxesSubplot:xlabel='rating', ylabel='Count'>

# %%
plt.figure(figsize=(12,10))
sn.set(style="darkgrid")
sn.countplot(y="release_year",data= net,order= net['release_year'].value_counts().index[0:15],hue=net['type'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='release_year'>

# %%
columns=['title','duration']
tv_shows = net[columns]
tv_shows
# Out:
#                       title   duration
# 0      Dick Johnson Is Dead     90 min
# 1             Blood & Water  2 Seasons
# 2                 Ganglands   1 Season
# 3     Jailbirds New Orleans   1 Season
# 4              Kota Factory  2 Seasons
# ...                     ...        ...
# 8802                 Zodiac    158 min
# 8803            Zombie Dumb  2 Seasons
# 8804             Zombieland     88 min
# 8805                   Zoom     88 min
# 8806                 Zubaan    111 min
#
# [8807 rows x 2 columns]

# %%
tv_shows = net.sort_values(by='duration',ascending=False)
tv_shows
# Out:
#      show_id     type                                  title  \
# 1329   s1330    Movie  The Misadventures of Hedi and Cokeman
# 6278   s6279    Movie                               Being AP
# 952     s953    Movie                   The Whole Nine Yards
# 6141   s6142    Movie                       American Hangman
# 929     s930    Movie                Dead Again in Tombstone
# ...      ...      ...                                    ...
# 6556   s6557  TV Show                          Dance Academy
# 2945   s2946  TV Show             Cagaster of an Insect Cage
# 5541   s5542    Movie                        Louis C.K. 2017
# 5794   s5795    Movie                  Louis C.K.: Hilarious
# 5813   s5814    Movie   Louis C.K.: Live at the Comedy Store
#
#                director                                               cast  \
# 1329       Julien Royal  Hedi Bouchenafa, Nassim Lyes, Fred Testot, Jul...
# 6278      Anthony Wonke                                         Tony McCoy
# ...

# %%
t3_shows = tv_shows[0:3]
t3_shows
# Out:
#      show_id   type                                  title       director  \
# 1329   s1330  Movie  The Misadventures of Hedi and Cokeman   Julien Royal
# 6278   s6279  Movie                               Being AP  Anthony Wonke
# 952     s953  Movie                   The Whole Nine Yards  Jonathan Lynn
#
#                                                    cast         country  \
# 1329  Hedi Bouchenafa, Nassim Lyes, Fred Testot, Jul...          France
# 6278                                         Tony McCoy  United Kingdom
# 952   Bruce Willis, Matthew Perry, Rosanna Arquette,...   United States
#
#              date_added  release_year rating duration  \
# 1329  February 10, 2021          2021  TV-MA   99 min
# 6278    August 15, 2016          2015  TV-14   99 min
# 952         May 1, 2021          2000      R   99 min
#
#                                               listed_in  \
# 1329                     Comedies, International Movies
# ...

# %%
plt.figure(figsize=(18,8))
sn.set(style="darkgrid")
sn.countplot(x="country", data=net, palette="Accent", order=net['country'].value_counts().index[0:15])
# Out:
# <AxesSubplot:xlabel='country', ylabel='count'>

# %%
net.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water           Others
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans           Others
# 4      s5  TV Show           Kota Factory           Others
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...    Not Mention
# 3                                                NaN    Not Mention
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
country_count=net['country'].value_counts().sort_values(ascending=False)
country_count=pd.DataFrame(country_count)
topcountries=country_count[0:5]
topcountries
# Out:
#                 country
# United States      2818
# India               972
# Not Mention         831
# United Kingdom      419
# Japan               245

# %%
plt.figure(figsize=(7,5)) # Yearwise count
sn.set(style="darkgrid")
ax = sn.countplot(y="release_year", 
     data=net, 
     palette="Set1", 
     order=net['release_year'].value_counts().index[0:15])
plt.title("Content release in years on Netflix vs Count")
# Out:
# Text(0.5, 1.0, 'Content release in years on Netflix vs Count')

# %%
sn.countplot(data =net, x = 'type', order=['TV Show', 'Movie'])
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
country_count=net['country'].value_counts().sort_values(ascending=True)
country_count=pd.DataFrame(country_count)
least_countries=country_count[0:7]
least_countries
# Out:
#                                                     country
# Georgia, Germany, France                                  1
# United Kingdom, United States, Dominican Republic         1
# United States, Poland                                     1
# Brazil, United States                                     1
# United Kingdom, France, Canada, Belgium, United...        1
# United Kingdom, Denmark, Canada, Croatia                  1
# United Kingdom, France, Germany, Spain                    1

# %%
plt.figure(figsize=(7,5))
sn.set(style="darkgrid")
sn.countplot(x="rating", 
             data=net, palette="Accent", order=netflix_movies['rating'].value_counts().index[0:5])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sn.set(style="darkgrid")
sn.countplot(x="rating", 
             data=net, palette="Accent", order=netflix_shows['rating'].value_counts().index[0:5])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sn.set(style="darkgrid")
sn.countplot(x="country", 
             data=net, palette="Accent", order=netflix_shows['country'].value_counts().index[0:3])
# Out:
# <AxesSubplot:xlabel='country', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sn.set(style="darkgrid")
sn.countplot(x="country", 
             data=net, palette="Accent", order=netflix_movies['country'].value_counts().index[0:3])
# Out:
# <AxesSubplot:xlabel='country', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sn.set(style="darkgrid")
sn.countplot(x="rating", 
             data=net, palette="Accent", order=netflix_movies['rating'].value_counts().index[0:3])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='count'>

# %%
plt.figure(figsize=(8, 6))
labels=['1 Season', '2 Season', '3 Season']
_,_,texts = plt.pie(net.duration.value_counts()[:3], labels=labels, autopct='%1.2f%%', startangle=90, 
                      explode=(0.0, 0.1, 0.2), colors=['lightblue', 'royalblue', 'lightgreen'])
plt.axis('equal')
plt.title('Seasons Available on Netflix', fontsize=20, fontweight='bold');
for text in texts:
    text.set_color('black')

# %%
net.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water           Others
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans           Others
# 4      s5  TV Show           Kota Factory           Others
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...    Not Mention
# 3                                                NaN    Not Mention
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
net[['mins','units']]=net['duration'].str.split(' ',expand=True)

# %%
net.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water           Others
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans           Others
# 4      s5  TV Show           Kota Factory           Others
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...    Not Mention
# 3                                                NaN    Not Mention
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
net.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          7982 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  mins          8804 non-null   object
#  13  units         8804 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 516.1+ KB

# %%
net['mins'] = net['mins'].astype('float32')

# %%
net.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water           Others
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...    Not Mention
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
net['mins'].max()
# Out:
# 312.0

# %%
net['mins'].min()
# Out:
# 1.0

# %%
net['mins'].mean()
# Out:
# 69.846886

# %%
plt.figure(figsize=(6,4))
sn.set(style="darkgrid")
sn.countplot(x="listed_in", 
             data=net, palette="Accent", order=netflix_movies['listed_in'].value_counts().index[0:5])
# Out:
# <AxesSubplot:xlabel='listed_in', ylabel='count'>

# %%
net.sample()
# Out:
#      show_id     type        title director cast      country  \
# 6618   s6619  TV Show  Diva Brides   Others  NaN  Not Mention
#
#            date_added  release_year rating  duration  \
# 6618  October 2, 2019          2017  TV-MA  1 Season
#
#                          listed_in  \
# 6618  British TV Shows, Reality TV
#
#                                             description  mins   units
# 6618  In this reality series, brides-to-be stop at n...   1.0  Season

# %%
net["type"].value_counts(normalize=1)*100
# Out:
# Movie      69.615079
# TV Show    30.384921
# Name: type, dtype: float64

# %%
released_year =net.release_year.value_counts()
released_year
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1961       1
# 1925       1
# 1947       1
# 1966       1
# Name: release_year, Length: 74, dtype: int64

# %%
rating = net["rating"].value_counts()
rating
# Out:
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %%
net["duration"] = net["duration"].astype("object")

# %%
net["release_year"].nunique()
# Out:
# 74

# %%
types =net['type'].value_counts()
types
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
t1 =net['type'].sort_values()
t1
# Out:
# 0         Movie
# 5641      Movie
# 5639      Movie
# 5638      Movie
# 5637      Movie
#          ...
# 2406    TV Show
# 5777    TV Show
# 2405    TV Show
# 5730    TV Show
# 4403    TV Show
# Name: type, Length: 8807, dtype: object
